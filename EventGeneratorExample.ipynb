# %% [markdown]
# # Example of how to sample collisions

# %%
import sampling
import numpy as np

# %%
T0       =  18e3  # Energy in eV
Density0 =  1e20  # Density in atoms m^-3
n0       =  100    # Collisions to sample

# %%
# Example for how to sample collisions

ElectronEnergy=T0
#
for n in range(0,n0):
    Distance, Theta, dT, CollisionTypeName = sampling.GetNextCollision(T=ElectronEnergy,Density=Density0)

    print("Collision of type <" + str(CollisionTypeName) + "> after distance " + str(round(Distance,2)) + " m")
    print("   Energy loss dT = " + str(round(dT,3)) + " eV  angle  dTh = "+str(round(Theta*180/np.pi,2))+ " deg")
    print("   New electron E = " + str(ElectronEnergy))
    print()

    ElectronEnergy = ElectronEnergy - dT
# Out:
# Collision of type <discrete_2> after distance 7.24 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.04 deg
#    New electron E = 18000.0
#
# Collision of type <continuum> after distance 184.45 m
#    Energy loss dT = 27.367 eV  angle  dTh = 2.14 deg
#    New electron E = 17989.79999806508
#
# Collision of type <discrete_2> after distance 20.07 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.06 deg
#    New electron E = 17962.4328619387
#
# Collision of type <discrete_2> after distance 57.08 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.04 deg
#    New electron E = 17952.232858719603
#
# Collision of type <elastic> after distance 73.91 m
#    Energy loss dT = 0.0 eV  angle  dTh = 0.34 deg
#    New electron E = 17942.0328568999
#
# Collision of type <elastic> after distance 5.2 m
#    Energy loss dT = 0.008 eV  angle  dTh = 2.92 deg
#    New electron E = 17942.032749337402
#
# Collision of type <discrete_2> after distance 41.79 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.13 deg
#    New electron E = 17942.024862528397
#
# Collision of type <continuum> after distance 65.48 m
#    Energy loss dT = 17.596 eV  angle  dTh = 0.13 deg
#    New electron E = 17931.824847726235
#
# Collision of type <discrete_2> after distance 81.19 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.61 deg
#    New electron E = 17914.229056062653
#
# Collision of type <discrete_2> after distance 3.01 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.15 deg
#    New electron E = 17904.028711665305
#
# Collision of type <discrete_2> after distance 8.6 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.35 deg
#    New electron E = 17893.82869044551
#
# Collision of type <discrete_2> after distance 29.05 m
#    Energy loss dT = 10.202 eV  angle  dTh = 1.29 deg
#    New electron E = 17883.62857478759
#
# Collision of type <discrete_2> after distance 31.66 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.29 deg
#    New electron E = 17873.427047814508
#
# Collision of type <discrete_2> after distance 13.08 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.05 deg
#    New electron E = 17863.226970612974
#
# Collision of type <continuum> after distance 13.64 m
#    Energy loss dT = 14.995 eV  angle  dTh = 1.12 deg
#    New electron E = 17853.02696833676
#
# Collision of type <continuum> after distance 66.3 m
#    Energy loss dT = 13.335 eV  angle  dTh = 0.04 deg
#    New electron E = 17838.03164157825
#
# Collision of type <continuum> after distance 124.53 m
#    Energy loss dT = 19.792 eV  angle  dTh = 0.2 deg
#    New electron E = 17824.69652263465
#
# Collision of type <discrete_4> after distance 65.14 m
#    Energy loss dT = 12.75 eV  angle  dTh = 0.04 deg
#    New electron E = 17804.904590222166
#
# Collision of type <discrete_3> after distance 83.59 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.02 deg
#    New electron E = 17792.154588315563
#
# Collision of type <discrete_2> after distance 3.46 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.02 deg
#    New electron E = 17780.065698817216
#
# Collision of type <discrete_2> after distance 93.34 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.02 deg
#    New electron E = 17769.86569808684
#
# Collision of type <discrete_2> after distance 126.73 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.16 deg
#    New electron E = 17759.665697454806
#
# Collision of type <discrete_2> after distance 19.51 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.22 deg
#    New electron E = 17749.465673695428
#
# Collision of type <discrete_2> after distance 15.62 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.13 deg
#    New electron E = 17739.265629907048
#
# Collision of type <discrete_2> after distance 30.53 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.42 deg
#    New electron E = 17729.065614290837
#
# Collision of type <continuum> after distance 2.54 m
#    Energy loss dT = 21.5 eV  angle  dTh = 1.25 deg
#    New electron E = 17718.865454578317
#
# Collision of type <discrete_2> after distance 2.1 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.2 deg
#    New electron E = 17697.364959627863
#
# Collision of type <discrete_2> after distance 40.28 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.08 deg
#    New electron E = 17687.16492185491
#
# Collision of type <discrete_3> after distance 46.26 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.02 deg
#    New electron E = 17676.964916167384
#
# Collision of type <discrete_2> after distance 82.57 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.44 deg
#    New electron E = 17664.87602671924
#
# Collision of type <discrete_2> after distance 3.34 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.03 deg
#    New electron E = 17654.675847646038
#
# Collision of type <discrete_3> after distance 29.16 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.06 deg
#    New electron E = 17644.475846325484
#
# Collision of type <discrete_3> after distance 5.82 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.08 deg
#    New electron E = 17632.386953352034
#
# Collision of type <continuum> after distance 21.44 m
#    Energy loss dT = 16.226 eV  angle  dTh = 0.03 deg
#    New electron E = 17620.298058678734
#
# Collision of type <continuum> after distance 6.53 m
#    Energy loss dT = 30.979 eV  angle  dTh = 0.45 deg
#    New electron E = 17604.072448018225
#
# Collision of type <continuum> after distance 11.21 m
#    Energy loss dT = 24.292 eV  angle  dTh = 0.22 deg
#    New electron E = 17573.09334586323
#
# Collision of type <discrete_2> after distance 22.58 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.17 deg
#    New electron E = 17548.80151632177
#
# Collision of type <discrete_2> after distance 171.82 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.07 deg
#    New electron E = 17538.60149098523
#
# Collision of type <continuum> after distance 6.94 m
#    Energy loss dT = 16.289 eV  angle  dTh = 0.01 deg
#    New electron E = 17528.401486860475
#
# Collision of type <continuum> after distance 37.36 m
#    Energy loss dT = 15.305 eV  angle  dTh = 0.87 deg
#    New electron E = 17512.112732332767
#
# Collision of type <discrete_2> after distance 10.2 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.12 deg
#    New electron E = 17496.8074040712
#
# Collision of type <discrete_2> after distance 30.28 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.08 deg
#    New electron E = 17486.607391755788
#
# Collision of type <discrete_2> after distance 10.88 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.15 deg
#    New electron E = 17476.40738531582
#
# Collision of type <discrete_2> after distance 8.07 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.22 deg
#    New electron E = 17466.207365245307
#
# Collision of type <discrete_2> after distance 23.2 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.17 deg
#    New electron E = 17456.007322077417
#
# Collision of type <continuum> after distance 13.63 m
#    Energy loss dT = 19.631 eV  angle  dTh = 0.77 deg
#    New electron E = 17445.807296464594
#
# Collision of type <discrete_2> after distance 109.53 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.09 deg
#    New electron E = 17426.175990580323
#
# Collision of type <discrete_2> after distance 22.75 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.05 deg
#    New electron E = 17415.975983322274
#
# Collision of type <discrete_2> after distance 142.88 m
#    Energy loss dT = 10.201 eV  angle  dTh = 1.07 deg
#    New electron E = 17405.77598122145
#
# Collision of type <discrete_2> after distance 5.06 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.37 deg
#    New electron E = 17395.574944869408
#
# Collision of type <continuum> after distance 23.31 m
#    Energy loss dT = 19.094 eV  angle  dTh = 0.8 deg
#    New electron E = 17385.37482212114
#
# Collision of type <discrete_4> after distance 24.34 m
#    Energy loss dT = 12.75 eV  angle  dTh = 0.2 deg
#    New electron E = 17366.280527694897
#
# Collision of type <discrete_3> after distance 72.41 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.11 deg
#    New electron E = 17353.530490497866
#
# Collision of type <discrete_2> after distance 22.66 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.4 deg
#    New electron E = 17341.44159097601
#
# Collision of type <discrete_2> after distance 8.57 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.03 deg
#    New electron E = 17331.241450701047
#
# Collision of type <continuum> after distance 62.02 m
#    Energy loss dT = 18.278 eV  angle  dTh = 0.11 deg
#    New electron E = 17321.041449774206
#
# Collision of type <discrete_2> after distance 39.17 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.03 deg
#    New electron E = 17302.7638954879
#
# Collision of type <discrete_2> after distance 70.94 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.12 deg
#    New electron E = 17292.563894428757
#
# Collision of type <continuum> after distance 48.83 m
#    Energy loss dT = 41.807 eV  angle  dTh = 1.58 deg
#    New electron E = 17282.363882121084
#
# Collision of type <discrete_2> after distance 32.13 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.31 deg
#    New electron E = 17240.557208835096
#
# Collision of type <discrete_2> after distance 9.52 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.57 deg
#    New electron E = 17230.357125887345
#
# Collision of type <discrete_2> after distance 39.75 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.04 deg
#    New electron E = 17220.156834625435
#
# Collision of type <continuum> after distance 27.09 m
#    Energy loss dT = 22.446 eV  angle  dTh = 0.1 deg
#    New electron E = 17209.95683266378
#
# Collision of type <discrete_3> after distance 9.09 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.37 deg
#    New electron E = 17187.510843879652
#
# Collision of type <continuum> after distance 106.8 m
#    Energy loss dT = 31.273 eV  angle  dTh = 1.26 deg
#    New electron E = 17175.42183104786
#
# Collision of type <continuum> after distance 28.63 m
#    Energy loss dT = 15.197 eV  angle  dTh = 1.48 deg
#    New electron E = 17144.14847689104
#
# Collision of type <continuum> after distance 13.81 m
#    Energy loss dT = 16.252 eV  angle  dTh = 0.67 deg
#    New electron E = 17128.951312613128
#
# Collision of type <continuum> after distance 32.75 m
#    Energy loss dT = 13.601 eV  angle  dTh = 0.09 deg
#    New electron E = 17112.699377880934
#
# Collision of type <elastic> after distance 37.51 m
#    Energy loss dT = 0.005 eV  angle  dTh = 2.37 deg
#    New electron E = 17099.097918614818
#
# Collision of type <discrete_2> after distance 91.21 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.02 deg
#    New electron E = 17099.09295220219
#
# Collision of type <continuum> after distance 11.64 m
#    Energy loss dT = 15.206 eV  angle  dTh = 0.54 deg
#    New electron E = 17088.892951668997
#
# Collision of type <discrete_2> after distance 14.48 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.07 deg
#    New electron E = 17073.687214179918
#
# Collision of type <continuum> after distance 0.92 m
#    Energy loss dT = 28.126 eV  angle  dTh = 1.45 deg
#    New electron E = 17063.48720977381
#
# Collision of type <discrete_2> after distance 0.15 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.38 deg
#    New electron E = 17035.361387962796
#
# Collision of type <discrete_3> after distance 14.85 m
#    Energy loss dT = 12.09 eV  angle  dTh = 1.34 deg
#    New electron E = 17025.16126327217
#
# Collision of type <discrete_3> after distance 7.35 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.06 deg
#    New electron E = 17013.070794865627
#
# Collision of type <discrete_2> after distance 32.42 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.23 deg
#    New electron E = 17000.981902662817
#
# Collision of type <discrete_2> after distance 4.88 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.31 deg
#    New electron E = 16990.781854896206
#
# Collision of type <elastic> after distance 87.58 m
#    Energy loss dT = 0.002 eV  angle  dTh = 1.44 deg
#    New electron E = 16980.581772085287
#
# Collision of type <continuum> after distance 34.05 m
#    Energy loss dT = 17.68 eV  angle  dTh = 0.04 deg
#    New electron E = 16980.579952502736
#
# Collision of type <discrete_3> after distance 60.3 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.49 deg
#    New electron E = 16962.900234721103
#
# Collision of type <continuum> after distance 6.57 m
#    Energy loss dT = 19.387 eV  angle  dTh = 0.27 deg
#    New electron E = 16950.811133898216
#
# Collision of type <continuum> after distance 14.54 m
#    Energy loss dT = 13.969 eV  angle  dTh = 0.52 deg
#    New electron E = 16931.42446089145
#
# Collision of type <elastic> after distance 27.0 m
#    Energy loss dT = 0.039 eV  angle  dTh = 6.66 deg
#    New electron E = 16917.455378675822
#
# Collision of type <continuum> after distance 97.1 m
#    Energy loss dT = 14.067 eV  angle  dTh = 0.14 deg
#    New electron E = 16917.416790804895
#
# Collision of type <discrete_2> after distance 4.88 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.0 deg
#    New electron E = 16903.349780034714
#
# Collision of type <discrete_2> after distance 14.7 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.02 deg
#    New electron E = 16893.1497797627
#
# Collision of type <discrete_2> after distance 70.09 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.31 deg
#    New electron E = 16882.94977903421
#
# Collision of type <discrete_2> after distance 33.57 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.01 deg
#    New electron E = 16872.749694618295
#
# Collision of type <discrete_2> after distance 6.23 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.27 deg
#    New electron E = 16862.549694189573
#
# Collision of type <discrete_3> after distance 79.67 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.04 deg
#    New electron E = 16852.34963088715
#
# Collision of type <elastic> after distance 20.79 m
#    Energy loss dT = 0.082 eV  angle  dTh = 9.72 deg
#    New electron E = 16840.260740514153
#
# Collision of type <discrete_2> after distance 11.81 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.01 deg
#    New electron E = 16840.178900154446
#
# Collision of type <continuum> after distance 23.46 m
#    Energy loss dT = 18.789 eV  angle  dTh = 0.1 deg
#    New electron E = 16829.97889981019
#
# Collision of type <continuum> after distance 9.0 m
#    Energy loss dT = 29.714 eV  angle  dTh = 0.4 deg
#    New electron E = 16811.190195671832
#
# Collision of type <discrete_3> after distance 192.1 m
#    Energy loss dT = 12.089 eV  angle  dTh = 0.29 deg
#    New electron E = 16781.47607988344
#
# Collision of type <discrete_2> after distance 31.25 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.34 deg
#    New electron E = 16769.38711550923
#
# Collision of type <continuum> after distance 12.13 m
#    Energy loss dT = 13.696 eV  angle  dTh = 0.24 deg
#    New electron E = 16759.187015785436
#
# Collision of type <continuum> after distance 7.97 m
#    Energy loss dT = 36.309 eV  angle  dTh = 0.74 deg
#    New electron E = 16745.4912372745
#
# Collision of type <discrete_2> after distance 4.37 m
#    Energy loss dT = 10.2 eV  angle  dTh = 0.27 deg
#    New electron E = 16709.181841766836
